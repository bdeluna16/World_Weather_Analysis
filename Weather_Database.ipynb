# %%
# Import the dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm the sufficient count
len(cities)
# Out:
# 755

# %%
# Import the requests library
import requests

# Import the API Key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9408ee0f5837093998035c128c19755c

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -------------------------------

# %%
# Loop through all of the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_desc = city_weather['weather'][0]['description']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Current Description": city_desc,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lorengau
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | zhigansk
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | kysyl-syr
# Processing Record 11 of Set 1 | muisne
# Processing Record 12 of Set 1 | yulara
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | meulaboh
# Processing Record 15 of Set 1 | methoni
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 1 | karpathos
# Processing Record 21 of Set 1 | bathsheba
# Processing Record 22 of Set 1 | natal
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | ugoofaaru
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | lixourion
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | yerbogachen
# Processing Record 31 of Set 1 | solnechnyy
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | voh
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | tilichiki
# Processing Record 41 of Set 1 | liverpool
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | alugan
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | halvad
# Processing Record 47 of Set 1 | dawson
# Processing Record 48 of Set 1 | atbasar
# Processing Record 49 of Set 1 | kirakira
# Processing Record 50 of Set 1 | lensk
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | novki
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | amudat
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | opuwo
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | seddon
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | champerico
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | sur
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | antalaha
# Processing Record 23 of Set 2 | corralillo
# Processing Record 24 of Set 2 | sungurlare
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | kabanjahe
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | micheweni
# Processing Record 31 of Set 2 | nome
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | iralaya
# Processing Record 34 of Set 2 | yar-sale
# Processing Record 35 of Set 2 | kargopol
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | college
# Processing Record 39 of Set 2 | buala
# Processing Record 40 of Set 2 | haapu
# City not found. Skipping...
# Processing Record 41 of Set 2 | iguape
# Processing Record 42 of Set 2 | mackay
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | vao
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | moratuwa
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | alyangula
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | ligayan
# Processing Record 2 of Set 3 | along
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | grindavik
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | mogadishu
# Processing Record 8 of Set 3 | kismayo
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | tisul
# Processing Record 11 of Set 3 | nemuro
# Processing Record 12 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 3 | pala
# Processing Record 14 of Set 3 | mehamn
# Processing Record 15 of Set 3 | sibu
# Processing Record 16 of Set 3 | padang
# Processing Record 17 of Set 3 | ulagan
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | aykhal
# Processing Record 20 of Set 3 | taree
# Processing Record 21 of Set 3 | gizo
# Processing Record 22 of Set 3 | greaca
# Processing Record 23 of Set 3 | paucartambo
# City not found. Skipping...
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | kothen
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | praia
# Processing Record 32 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | kashi
# Processing Record 35 of Set 3 | san quintin
# Processing Record 36 of Set 3 | hongjiang
# Processing Record 37 of Set 3 | nanortalik
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | tabou
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | liberty
# Processing Record 42 of Set 3 | xuddur
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | gorontalo
# Processing Record 46 of Set 3 | la ronge
# Processing Record 47 of Set 3 | candolim
# Processing Record 48 of Set 3 | provideniya
# Processing Record 49 of Set 3 | tura
# Processing Record 50 of Set 3 | soyo
# Processing Record 1 of Set 4 | ilinskiy
# Processing Record 2 of Set 4 | karlstad
# Processing Record 3 of Set 4 | fortuna
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | messina
# Processing Record 6 of Set 4 | poum
# Processing Record 7 of Set 4 | parati
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | kaeo
# Processing Record 10 of Set 4 | aswan
# Processing Record 11 of Set 4 | staryy nadym
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | mumford
# Processing Record 14 of Set 4 | bhadrachalam
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | port hueneme
# Processing Record 17 of Set 4 | miraflores
# Processing Record 18 of Set 4 | sakaiminato
# Processing Record 19 of Set 4 | novomikhaylovskiy
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | loiza
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | wallaceburg
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | lahat
# Processing Record 26 of Set 4 | palmer
# Processing Record 27 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | promyshlennyy
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | pag
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | la asuncion
# Processing Record 36 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 4 | vila do maio
# Processing Record 38 of Set 4 | najran
# Processing Record 39 of Set 4 | akcakoca
# Processing Record 40 of Set 4 | sao gabriel da cachoeira
# Processing Record 41 of Set 4 | igrim
# Processing Record 42 of Set 4 | kloulklubed
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | khrebtovaya
# Processing Record 45 of Set 4 | trelew
# Processing Record 46 of Set 4 | manzanillo
# Processing Record 47 of Set 4 | matagami
# Processing Record 48 of Set 4 | tatawin
# Processing Record 49 of Set 4 | fort nelson
# Processing Record 50 of Set 4 | bambanglipuro
# Processing Record 1 of Set 5 | wollongong
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | linapacan
# City not found. Skipping...
# Processing Record 4 of Set 5 | port hardy
# Processing Record 5 of Set 5 | paamiut
# Processing Record 6 of Set 5 | saldanha
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | port moresby
# Processing Record 9 of Set 5 | cabedelo
# Processing Record 10 of Set 5 | novyy urengoy
# Processing Record 11 of Set 5 | alghero
# Processing Record 12 of Set 5 | rocky mountain house
# Processing Record 13 of Set 5 | marawi
# Processing Record 14 of Set 5 | elizabeth city
# Processing Record 15 of Set 5 | trairi
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | henties bay
# Processing Record 18 of Set 5 | palatka
# Processing Record 19 of Set 5 | anadyr
# Processing Record 20 of Set 5 | avera
# Processing Record 21 of Set 5 | eyl
# Processing Record 22 of Set 5 | pangnirtung
# Processing Record 23 of Set 5 | pestravka
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | namtsy
# Processing Record 26 of Set 5 | muravlenko
# Processing Record 27 of Set 5 | rabo de peixe
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 5 | pandamatenga
# Processing Record 32 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 33 of Set 5 | ferme-neuve
# Processing Record 34 of Set 5 | morgan city
# Processing Record 35 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 5 | dalnegorsk
# Processing Record 37 of Set 5 | paramonga
# Processing Record 38 of Set 5 | preobrazheniye
# Processing Record 39 of Set 5 | araguacu
# Processing Record 40 of Set 5 | colares
# Processing Record 41 of Set 5 | nannilam
# Processing Record 42 of Set 5 | tabas
# Processing Record 43 of Set 5 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 44 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 5 | swan river
# Processing Record 46 of Set 5 | salumbar
# Processing Record 47 of Set 5 | isangel
# Processing Record 48 of Set 5 | lagoa
# Processing Record 49 of Set 5 | hamilton
# Processing Record 50 of Set 5 | ambilobe
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | hay river
# Processing Record 3 of Set 6 | ballina
# Processing Record 4 of Set 6 | edd
# Processing Record 5 of Set 6 | dzhebariki-khaya
# Processing Record 6 of Set 6 | joshimath
# Processing Record 7 of Set 6 | nhulunbuy
# Processing Record 8 of Set 6 | sohag
# Processing Record 9 of Set 6 | pisco
# Processing Record 10 of Set 6 | mildura
# Processing Record 11 of Set 6 | xining
# Processing Record 12 of Set 6 | port-gentil
# Processing Record 13 of Set 6 | mahanje
# Processing Record 14 of Set 6 | victoria
# Processing Record 15 of Set 6 | almaznyy
# Processing Record 16 of Set 6 | springfield
# Processing Record 17 of Set 6 | algeciras
# Processing Record 18 of Set 6 | boende
# Processing Record 19 of Set 6 | kaitangata
# Processing Record 20 of Set 6 | dudinka
# Processing Record 21 of Set 6 | calabozo
# Processing Record 22 of Set 6 | nioro
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | erenhot
# Processing Record 25 of Set 6 | wajima
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | santa rosalia
# Processing Record 28 of Set 6 | nkayi
# Processing Record 29 of Set 6 | harqalah
# Processing Record 30 of Set 6 | byron bay
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | harper
# Processing Record 33 of Set 6 | ponta delgada
# Processing Record 34 of Set 6 | noumea
# Processing Record 35 of Set 6 | zeya
# Processing Record 36 of Set 6 | quilmana
# Processing Record 37 of Set 6 | verkhoyansk
# Processing Record 38 of Set 6 | kushiro
# Processing Record 39 of Set 6 | high level
# Processing Record 40 of Set 6 | dingle
# Processing Record 41 of Set 6 | inyonga
# Processing Record 42 of Set 6 | marsh harbour
# Processing Record 43 of Set 6 | berezovyy
# Processing Record 44 of Set 6 | pucallpa
# Processing Record 45 of Set 6 | pimentel
# Processing Record 46 of Set 6 | los llanos de aridane
# Processing Record 47 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 6 | puerto quijarro
# Processing Record 49 of Set 6 | rio gallegos
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | lima
# Processing Record 2 of Set 7 | ushtobe
# Processing Record 3 of Set 7 | sarakhs
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | campo grande
# Processing Record 6 of Set 7 | hualmay
# Processing Record 7 of Set 7 | kudahuvadhoo
# Processing Record 8 of Set 7 | abay
# Processing Record 9 of Set 7 | yumen
# Processing Record 10 of Set 7 | hofn
# Processing Record 11 of Set 7 | kirkland lake
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | bereda
# Processing Record 14 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 7 | miandrivazo
# Processing Record 16 of Set 7 | santa cruz
# Processing Record 17 of Set 7 | kuala kedah
# Processing Record 18 of Set 7 | bria
# Processing Record 19 of Set 7 | kokkola
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 7 | progreso
# Processing Record 23 of Set 7 | neiafu
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | zhangye
# Processing Record 26 of Set 7 | soller
# Processing Record 27 of Set 7 | mar del plata
# Processing Record 28 of Set 7 | banjar
# Processing Record 29 of Set 7 | brigantine
# Processing Record 30 of Set 7 | khuzhir
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | laguna
# Processing Record 33 of Set 7 | kijang
# Processing Record 34 of Set 7 | buarcos
# Processing Record 35 of Set 7 | gloversville
# Processing Record 36 of Set 7 | adrar
# Processing Record 37 of Set 7 | ilulissat
# Processing Record 38 of Set 7 | raymondville
# Processing Record 39 of Set 7 | manaus
# Processing Record 40 of Set 7 | pauini
# Processing Record 41 of Set 7 | batagay-alyta
# Processing Record 42 of Set 7 | haines junction
# Processing Record 43 of Set 7 | port hawkesbury
# Processing Record 44 of Set 7 | bungu
# Processing Record 45 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 7 | jiayuguan
# Processing Record 47 of Set 7 | buchanan
# Processing Record 48 of Set 7 | zmievka
# City not found. Skipping...
# Processing Record 49 of Set 7 | lusambo
# Processing Record 50 of Set 7 | sinnamary
# Processing Record 1 of Set 8 | olinda
# Processing Record 2 of Set 8 | huarmey
# Processing Record 3 of Set 8 | bambous virieux
# Processing Record 4 of Set 8 | parker
# Processing Record 5 of Set 8 | belaya gora
# Processing Record 6 of Set 8 | beyneu
# Processing Record 7 of Set 8 | fukue
# Processing Record 8 of Set 8 | tecoanapa
# Processing Record 9 of Set 8 | paris
# Processing Record 10 of Set 8 | ayan
# Processing Record 11 of Set 8 | elko
# Processing Record 12 of Set 8 | kulhudhuffushi
# Processing Record 13 of Set 8 | newtownards
# Processing Record 14 of Set 8 | iisalmi
# Processing Record 15 of Set 8 | kodino
# Processing Record 16 of Set 8 | ahuimanu
# Processing Record 17 of Set 8 | aberdeen
# Processing Record 18 of Set 8 | ahipara
# Processing Record 19 of Set 8 | marshall
# Processing Record 20 of Set 8 | sivaki
# Processing Record 21 of Set 8 | gossaigaon
# Processing Record 22 of Set 8 | rodrigues alves
# Processing Record 23 of Set 8 | mulchen
# Processing Record 24 of Set 8 | victor harbor
# Processing Record 25 of Set 8 | slupsk
# Processing Record 26 of Set 8 | hagenow
# Processing Record 27 of Set 8 | carauari
# Processing Record 28 of Set 8 | muros
# Processing Record 29 of Set 8 | saint-honore
# Processing Record 30 of Set 8 | medicina
# Processing Record 31 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 8 | ossora
# Processing Record 33 of Set 8 | zhanaozen
# Processing Record 34 of Set 8 | baykit
# Processing Record 35 of Set 8 | tocopilla
# Processing Record 36 of Set 8 | torbay
# Processing Record 37 of Set 8 | milazzo
# Processing Record 38 of Set 8 | tevaitoa
# Processing Record 39 of Set 8 | sergeyevka
# Processing Record 40 of Set 8 | manokwari
# Processing Record 41 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 8 | port hedland
# Processing Record 43 of Set 8 | san cristobal
# Processing Record 44 of Set 8 | esperance
# Processing Record 45 of Set 8 | mayo
# Processing Record 46 of Set 8 | arlit
# Processing Record 47 of Set 8 | kaniama
# Processing Record 48 of Set 8 | batsfjord
# Processing Record 49 of Set 8 | touros
# Processing Record 50 of Set 8 | simplicio mendes
# Processing Record 1 of Set 9 | saint-georges
# Processing Record 2 of Set 9 | sept-iles
# Processing Record 3 of Set 9 | bengkulu
# Processing Record 4 of Set 9 | okhotsk
# Processing Record 5 of Set 9 | kununurra
# Processing Record 6 of Set 9 | katangli
# Processing Record 7 of Set 9 | ridgecrest
# Processing Record 8 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 9 | impfondo
# Processing Record 10 of Set 9 | mayumba
# Processing Record 11 of Set 9 | kavaratti
# Processing Record 12 of Set 9 | kommunarka
# Processing Record 13 of Set 9 | broken hill
# Processing Record 14 of Set 9 | santander
# Processing Record 15 of Set 9 | nouadhibou
# Processing Record 16 of Set 9 | krasnyy chikoy
# Processing Record 17 of Set 9 | yantzaza
# Processing Record 18 of Set 9 | te anau
# Processing Record 19 of Set 9 | kiama
# Processing Record 20 of Set 9 | maneadero
# Processing Record 21 of Set 9 | sibolga
# Processing Record 22 of Set 9 | ostroveni
# Processing Record 23 of Set 9 | vila velha
# Processing Record 24 of Set 9 | sobolevo
# Processing Record 25 of Set 9 | eureka
# Processing Record 26 of Set 9 | fjerritslev
# Processing Record 27 of Set 9 | oktyabrskoye
# Processing Record 28 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 9 | desaguadero
# Processing Record 30 of Set 9 | saint-francois
# Processing Record 31 of Set 9 | ardahan
# Processing Record 32 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 9 | svarstad
# Processing Record 34 of Set 9 | karakol
# Processing Record 35 of Set 9 | santa maria
# Processing Record 36 of Set 9 | huilong
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | north bend
# Processing Record 39 of Set 9 | dhidhdhoo
# Processing Record 40 of Set 9 | khandyga
# Processing Record 41 of Set 9 | namatanai
# Processing Record 42 of Set 9 | texarkana
# Processing Record 43 of Set 9 | jawar
# Processing Record 44 of Set 9 | saint-paul
# Processing Record 45 of Set 9 | roald
# Processing Record 46 of Set 9 | shar
# Processing Record 47 of Set 9 | mokrous
# Processing Record 48 of Set 9 | martapura
# Processing Record 49 of Set 9 | gafanha da encarnacao
# Processing Record 50 of Set 9 | leningradskiy
# Processing Record 1 of Set 10 | businga
# Processing Record 2 of Set 10 | namibe
# Processing Record 3 of Set 10 | okha
# Processing Record 4 of Set 10 | kommunisticheskiy
# Processing Record 5 of Set 10 | bubaque
# Processing Record 6 of Set 10 | ust-koksa
# Processing Record 7 of Set 10 | guadalajara
# Processing Record 8 of Set 10 | swinoujscie
# Processing Record 9 of Set 10 | teahupoo
# Processing Record 10 of Set 10 | beloha
# Processing Record 11 of Set 10 | portel
# Processing Record 12 of Set 10 | pontes e lacerda
# Processing Record 13 of Set 10 | puerto colombia
# Processing Record 14 of Set 10 | waingapu
# Processing Record 15 of Set 10 | gobabis
# Processing Record 16 of Set 10 | ondo
# Processing Record 17 of Set 10 | apsheronsk
# Processing Record 18 of Set 10 | sao filipe
# Processing Record 19 of Set 10 | ionia
# Processing Record 20 of Set 10 | arawa
# Processing Record 21 of Set 10 | dedougou
# Processing Record 22 of Set 10 | khandagayty
# Processing Record 23 of Set 10 | teseney
# Processing Record 24 of Set 10 | husavik
# Processing Record 25 of Set 10 | rudbar
# Processing Record 26 of Set 10 | aksarka
# Processing Record 27 of Set 10 | arman
# Processing Record 28 of Set 10 | katsuura
# Processing Record 29 of Set 10 | vannes
# Processing Record 30 of Set 10 | saint-felicien
# Processing Record 31 of Set 10 | kilindoni
# Processing Record 32 of Set 10 | olga
# Processing Record 33 of Set 10 | yeppoon
# Processing Record 34 of Set 10 | sukumo
# Processing Record 35 of Set 10 | pundaguitan
# Processing Record 36 of Set 10 | freeport
# Processing Record 37 of Set 10 | pervomayskoye
# Processing Record 38 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | nuuk
# Processing Record 41 of Set 10 | vaitape
# Processing Record 42 of Set 10 | griffith
# Processing Record 43 of Set 10 | zyryanka
# Processing Record 44 of Set 10 | vestmannaeyjar
# Processing Record 45 of Set 10 | wenling
# Processing Record 46 of Set 10 | severomuysk
# Processing Record 47 of Set 10 | paragominas
# Processing Record 48 of Set 10 | goulburn
# Processing Record 49 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 10 | carutapera
# Processing Record 1 of Set 11 | chifeng
# Processing Record 2 of Set 11 | uvalde
# Processing Record 3 of Set 11 | makakilo city
# Processing Record 4 of Set 11 | gazojak
# Processing Record 5 of Set 11 | tarko-sale
# Processing Record 6 of Set 11 | tugalan
# City not found. Skipping...
# Processing Record 7 of Set 11 | yuli
# Processing Record 8 of Set 11 | halifax
# Processing Record 9 of Set 11 | virden
# Processing Record 10 of Set 11 | saint-pierre
# Processing Record 11 of Set 11 | houma
# Processing Record 12 of Set 11 | dicabisagan
# Processing Record 13 of Set 11 | bud
# Processing Record 14 of Set 11 | kargil
# Processing Record 15 of Set 11 | nyurba
# Processing Record 16 of Set 11 | san pedro
# Processing Record 17 of Set 11 | udachnyy
# Processing Record 18 of Set 11 | fairbanks
# Processing Record 19 of Set 11 | den helder
# Processing Record 20 of Set 11 | richards bay
# Processing Record 21 of Set 11 | coquimbo
# Processing Record 22 of Set 11 | saint-augustin
# Processing Record 23 of Set 11 | lake city
# Processing Record 24 of Set 11 | limon
# Processing Record 25 of Set 11 | veles
# Processing Record 26 of Set 11 | mount isa
# Processing Record 27 of Set 11 | evensk
# Processing Record 28 of Set 11 | amberley
# Processing Record 29 of Set 11 | alice springs
# Processing Record 30 of Set 11 | delta del tigre
# Processing Record 31 of Set 11 | moron
# Processing Record 32 of Set 11 | casper
# Processing Record 33 of Set 11 | livingston
# Processing Record 34 of Set 11 | krasnyy yar
# Processing Record 35 of Set 11 | vardo
# Processing Record 36 of Set 11 | herat
# Processing Record 37 of Set 11 | kosh-agach
# Processing Record 38 of Set 11 | hovd
# Processing Record 39 of Set 11 | smithers
# Processing Record 40 of Set 11 | khatanga
# Processing Record 41 of Set 11 | praia da vitoria
# Processing Record 42 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 11 | abu dhabi
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | talnakh
# Processing Record 46 of Set 11 | ozernovskiy
# Processing Record 47 of Set 11 | san juan
# Processing Record 48 of Set 11 | velasco ibarra
# Processing Record 49 of Set 11 | peleduy
# Processing Record 50 of Set 11 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 1 of Set 12 | oinoussai
# City not found. Skipping...
# Processing Record 2 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 12 | kieta
# Processing Record 4 of Set 12 | llandrindod wells
# Processing Record 5 of Set 12 | ji-parana
# City not found. Skipping...
# Processing Record 6 of Set 12 | mayor pablo lagerenza
# Processing Record 7 of Set 12 | temyasovo
# Processing Record 8 of Set 12 | thongwa
# Processing Record 9 of Set 12 | ixtapa
# Processing Record 10 of Set 12 | tazovskiy
# Processing Record 11 of Set 12 | east london
# Processing Record 12 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 12 | cacoal
# Processing Record 14 of Set 12 | isabela
# Processing Record 15 of Set 12 | gorgopi
# Processing Record 16 of Set 12 | qandala
# Processing Record 17 of Set 12 | rocha
# Processing Record 18 of Set 12 | chimbote
# Processing Record 19 of Set 12 | bilma
# Processing Record 20 of Set 12 | hithadhoo
# Processing Record 21 of Set 12 | raton
# Processing Record 22 of Set 12 | prado
# Processing Record 23 of Set 12 | flin flon
# Processing Record 24 of Set 12 | biak
# Processing Record 25 of Set 12 | belyy yar
# Processing Record 26 of Set 12 | road town
# Processing Record 27 of Set 12 | souillac
# Processing Record 28 of Set 12 | armidale
# Processing Record 29 of Set 12 | aksu
# Processing Record 30 of Set 12 | monte carmelo
# Processing Record 31 of Set 12 | lokosovo
# Processing Record 32 of Set 12 | aromashevo
# Processing Record 33 of Set 12 | lamu
# Processing Record 34 of Set 12 | anantapur
# Processing Record 35 of Set 12 | santa cruz de tenerife
# Processing Record 36 of Set 12 | kisangani
# Processing Record 37 of Set 12 | calama
# Processing Record 38 of Set 12 | codo
# Processing Record 39 of Set 12 | newport
# Processing Record 40 of Set 12 | sao jose da coroa grande
# Processing Record 41 of Set 12 | krasnoselkup
# Processing Record 42 of Set 12 | shenjiamen
# Processing Record 43 of Set 12 | diego de almagro
# Processing Record 44 of Set 12 | lakes entrance
# Processing Record 45 of Set 12 | qaqortoq
# Processing Record 46 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 12 | saint-joseph
# Processing Record 48 of Set 12 | sao felix do xingu
# Processing Record 49 of Set 12 | adrasmon
# Processing Record 50 of Set 12 | yalova
# Processing Record 1 of Set 13 | campechuela
# Processing Record 2 of Set 13 | semirom
# Processing Record 3 of Set 13 | yurginskoye
# Processing Record 4 of Set 13 | chara
# Processing Record 5 of Set 13 | huaibei
# Processing Record 6 of Set 13 | bowen
# Processing Record 7 of Set 13 | zatoka
# Processing Record 8 of Set 13 | sheltozero
# Processing Record 9 of Set 13 | erzin
# Processing Record 10 of Set 13 | chicama
# Processing Record 11 of Set 13 | necochea
# Processing Record 12 of Set 13 | visby
# Processing Record 13 of Set 13 | shaoguan
# Processing Record 14 of Set 13 | langsa
# Processing Record 15 of Set 13 | geraldton
# Processing Record 16 of Set 13 | yaan
# Processing Record 17 of Set 13 | cam ranh
# Processing Record 18 of Set 13 | lubumbashi
# Processing Record 19 of Set 13 | fayaoue
# Processing Record 20 of Set 13 | beian
# Processing Record 21 of Set 13 | bucerias
# Processing Record 22 of Set 13 | plaisance-du-touch
# Processing Record 23 of Set 13 | suao
# City not found. Skipping...
# Processing Record 24 of Set 13 | cosala
# Processing Record 25 of Set 13 | ewa beach
# Processing Record 26 of Set 13 | coronel vivida
# Processing Record 27 of Set 13 | bandarbeyla
# Processing Record 28 of Set 13 | caravelas
# Processing Record 29 of Set 13 | staryy oskol
# Processing Record 30 of Set 13 | sisimiut
# Processing Record 31 of Set 13 | agadir
# Processing Record 32 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 13 | akyab
# Processing Record 34 of Set 13 | talcahuano
# Processing Record 35 of Set 13 | celestun
# Processing Record 36 of Set 13 | ranong
# Processing Record 37 of Set 13 | kungsbacka
# Processing Record 38 of Set 13 | boa vista
# Processing Record 39 of Set 13 | morant bay
# Processing Record 40 of Set 13 | praxedis guerrero
# Processing Record 41 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 42 of Set 13 | zharkent
# Processing Record 43 of Set 13 | coalcoman
# City not found. Skipping...
# Processing Record 44 of Set 13 | ruteng
# Processing Record 45 of Set 13 | myre
# Processing Record 46 of Set 13 | asau
# Processing Record 47 of Set 13 | robertsport
# Processing Record 48 of Set 13 | baillif
# Processing Record 49 of Set 13 | ust-kalmanka
# Processing Record 50 of Set 13 | karratha
# Processing Record 1 of Set 14 | samana
# Processing Record 2 of Set 14 | labuhan
# Processing Record 3 of Set 14 | cascavel
# Processing Record 4 of Set 14 | ucluelet
# Processing Record 5 of Set 14 | sal rei
# Processing Record 6 of Set 14 | timmins
# Processing Record 7 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 14 | tomatlan
# Processing Record 9 of Set 14 | banovce
# City not found. Skipping...
# Processing Record 10 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 14 | nizhniy ingash
# Processing Record 12 of Set 14 | luganville
# Processing Record 13 of Set 14 | kiomboi
# Processing Record 14 of Set 14 | kyra
# Processing Record 15 of Set 14 | sturgeon bay
# Processing Record 16 of Set 14 | ingham
# Processing Record 17 of Set 14 | coihaique
# Processing Record 18 of Set 14 | caska
# Processing Record 19 of Set 14 | vallenar
# Processing Record 20 of Set 14 | tuy hoa
# Processing Record 21 of Set 14 | yichun
# Processing Record 22 of Set 14 | nuevo progreso
# Processing Record 23 of Set 14 | kati
# Processing Record 24 of Set 14 | naze
# Processing Record 25 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 14 | nenjiang
# Processing Record 27 of Set 14 | sioux lookout
# Processing Record 28 of Set 14 | whitehorse
# Processing Record 29 of Set 14 | marquette
# Processing Record 30 of Set 14 | skjervoy
# Processing Record 31 of Set 14 | hauterive
# Processing Record 32 of Set 14 | inuvik
# Processing Record 33 of Set 14 | rehoboth
# Processing Record 34 of Set 14 | payakumbuh
# Processing Record 35 of Set 14 | sorong
# Processing Record 36 of Set 14 | sorland
# Processing Record 37 of Set 14 | auxerre
# Processing Record 38 of Set 14 | mogok
# Processing Record 39 of Set 14 | ostersund
# Processing Record 40 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 14 | mikkeli
# Processing Record 42 of Set 14 | umm lajj
# Processing Record 43 of Set 14 | whitianga
# Processing Record 44 of Set 14 | yarmouth
# Processing Record 45 of Set 14 | cuamba
# Processing Record 46 of Set 14 | vermilion
# Processing Record 47 of Set 14 | buraydah
# Processing Record 48 of Set 14 | hervey bay
# Processing Record 49 of Set 14 | ryotsu
# Processing Record 50 of Set 14 | mumbwa
# Processing Record 1 of Set 15 | vanimo
# Processing Record 2 of Set 15 | tawau
# Processing Record 3 of Set 15 | tual
# Processing Record 4 of Set 15 | samarai
# Processing Record 5 of Set 15 | filingue
# Processing Record 6 of Set 15 | yermekeyevo
# Processing Record 7 of Set 15 | rovaniemi
# Processing Record 8 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 15 | jiazi
# Processing Record 10 of Set 15 | cap malheureux
# Processing Record 11 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 15 | batasan
# Processing Record 13 of Set 15 | rumoi
# Processing Record 14 of Set 15 | vasteras
# Processing Record 15 of Set 15 | sweetwater
# Processing Record 16 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 15 | nobeoka
# Processing Record 18 of Set 15 | yerkoy
# Processing Record 19 of Set 15 | temirtau
# Processing Record 20 of Set 15 | beringovskiy
# Processing Record 21 of Set 15 | homer
# Processing Record 22 of Set 15 | apastovo
# Processing Record 23 of Set 15 | riohacha
# Processing Record 24 of Set 15 | half moon bay
# Processing Record 25 of Set 15 | bhiwani
# Processing Record 26 of Set 15 | malakal
# Processing Record 27 of Set 15 | marigot
# Processing Record 28 of Set 15 | caluquembe
# Processing Record 29 of Set 15 | kasama
# Processing Record 30 of Set 15 | papetoai
# Processing Record 31 of Set 15 | karachi
# Processing Record 32 of Set 15 | ubinskoye
# Processing Record 33 of Set 15 | ola
# Processing Record 34 of Set 15 | rence
# Processing Record 35 of Set 15 | teluknaga
# Processing Record 36 of Set 15 | antofagasta
# Processing Record 37 of Set 15 | mawlaik
# Processing Record 38 of Set 15 | qixingtai
# Processing Record 39 of Set 15 | macon
# Processing Record 40 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 15 | panguna
# Processing Record 42 of Set 15 | kozhevnikovo
# Processing Record 43 of Set 15 | bilibino
# Processing Record 44 of Set 15 | teknaf
# Processing Record 45 of Set 15 | sharhorod
# Processing Record 46 of Set 15 | puerto escondido
# Processing Record 47 of Set 15 | ndele
# Processing Record 48 of Set 15 | saryozek
# Processing Record 49 of Set 15 | thunder bay
# Processing Record 50 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 16 | westport
# Processing Record 2 of Set 16 | sulangan
# Processing Record 3 of Set 16 | moerai
# Processing Record 4 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 16 | norrtalje
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Loop through all the cities in our list
for i in range(len(cities)):
    
    # Group cities in cets of 50 for logging purposes
    if (i % 50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + "i"

# %%
print(len(cities))
# Out:
# 755

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat Current Description     Lng  Max Temp  Humidity  \
# 0     Lorengau  -2.02          light rain  147.27     77.05        92
# 1      Ushuaia -54.80    scattered clouds  -68.30     30.20        80
# 2      Rikitea -23.12           clear sky -134.97     71.65        83
# 3  New Norfolk -42.78          light rain  147.06     48.99        76
# 4    Mahebourg -20.41         shower rain   57.70     73.40        69
# 5    Busselton -33.65          few clouds  115.33     64.99        43
# 6     Zhigansk  66.77           clear sky  123.37     54.05        45
# 7      Qaanaaq  77.48     overcast clouds  -69.36     35.91        88
# 8    Kysyl-Syr  63.90           clear sky  122.76     58.96        42
# 9       Muisne   0.60     overcast clouds  -80.03     71.92        86
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100       19.33      PG  2020-08-24 06:31:36
# 1          40        4.70      AR  2020-08-24 06:31:37
# 2           2       18.48      PF  2020-08-24 06:31:37
# 3          39        1.99      AU  2020-08-24 06:31:37
# 4          75       17.22      MU  2020-08-24 06:31:37
# 5          19        5.95      AU  2020-08-24 06:31:38
# 6           0        7.00      RU  2020-08-24 06:31:38
# 7         100        4.83      GL  2020-08-24 06:31:38
# 8           1        7.78      RU  2020-08-24 06:31:39
# 9         100       10.38      EC  2020-08-24 06:31:39

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Lorengau      PG  -2.02  147.27     77.05        92         100
# 1      Ushuaia      AR -54.80  -68.30     30.20        80          40
# 2      Rikitea      PF -23.12 -134.97     71.65        83           2
# 3  New Norfolk      AU -42.78  147.06     48.99        76          39
# 4    Mahebourg      MU -20.41   57.70     73.40        69          75
# 5    Busselton      AU -33.65  115.33     64.99        43          19
# 6     Zhigansk      RU  66.77  123.37     54.05        45           0
# 7      Qaanaaq      GL  77.48  -69.36     35.91        88         100
# 8    Kysyl-Syr      RU  63.90  122.76     58.96        42           1
# 9       Muisne      EC   0.60  -80.03     71.92        86         100
#
#    Wind Speed Current Description
# 0       19.33          light rain
# 1        4.70    scattered clouds
# 2       18.48           clear sky
# 3        1.99          light rain
# 4       17.22         shower rain
# 5        5.95          few clouds
# 6        7.00           clear sky
# 7        4.83     overcast clouds
# 8        7.78           clear sky
# 9       10.38     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
